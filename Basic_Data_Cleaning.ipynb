# %%
import pandas as pd

df = pd.read_csv(r"D:\Document\archive\Combined_dataset.csv")

print("Shape:", df.shape)
print(df.columns.tolist())
# Out:
# Shape: (1000, 24)
# ['product_id', 'title', 'product_description', 'rating', 'ratings_count', 'initial_price', 'discount', 'final_price', 'currency', 'images', 'delivery_options', 'product_details', 'breadcrumbs', 'product_specifications', 'amount_of_stars', 'what_customers_said', 'seller_name', 'sizes', 'videos', 'seller_information', 'variations', 'best_offer', 'more_offers', 'category']

# %%
# Check missing values
print("Missing Values:")
print(df.isnull().sum())

# Remove duplicates
df = df.drop_duplicates()

# Create derived column
df["price_difference"] = df["initial_price"] - df["final_price"]

# Basic statistics
print("\nDataset Shape After Cleaning:")
print(df.shape)

print("\nSummary Statistics:")
print(df.describe())

# Save cleaned dataset
df.to_csv("cleaned_dataset.csv", index=False)

print("\nCleaned dataset saved as cleaned_dataset.csv")
# Out:
# Missing Values:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5 # Remove duplicates
#       6 df = df.drop_duplicates()
#       7
#       8 # Create derived column
# ----> 9 df["price_difference"] = df["initial_price"] - df["final_price"]
#      10
#      11 # Basic statistics
#      12 print("\nDataset Shape After Cleaning:")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\series.py:6751, in Series._arith_method(self, other, op)
#    6749 def _arith_method(self, other, op):
#    6750     self, other = self._align_for_op(other)
# -> 6751     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\base.py:1644, in IndexOpsMixin._arith_method(self, other, op)
#    1641     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1643 with np.errstate(all="ignore"):
# -> 1644     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1646 return self._construct_result(result, name=res_name, other=other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\ops\array_ops.py:279, in arithmetic_op(left, right, op)
#     270 right = ensure_wrapped_if_datetimelike(right)
#     272 if (
#     273     should_extension_dispatch(left, right)
#     274     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)    277     # Timedelta/Timestamp and other custom scalars are included in the check
#     278     # because numexpr will fail on it, see GH#31457
# --> 279     res_values = op(left, right)
#     280 else:
#     281     # TODO we should handle EAs consistently and move this check before the if/else
#     282     # (https://github.com/pandas-dev/pandas/issues/41165)
#     283     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     285     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\arrays\numpy_.py:212, in NumpyExtensionArray.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     205 def __array_ufunc__(self, ufunc: np.ufunc, method: str, *inputs, **kwargs):
#     206     # Lightly modified version of
#     207     # https://numpy.org/doc/stable/reference/generated/numpy.lib.mixins.NDArrayOperatorsMixin.html
#     208     # The primary modification is not boxing scalar return values
#     209     # in NumpyExtensionArray, since pandas' ExtensionArrays are 1-d.
#     210     out = kwargs.get("out", ())
# --> 212     result = arraylike.maybe_dispatch_ufunc_to_dunder_op(
#     213         self, ufunc, method, *inputs, **kwargs
#     214     )
#     215     if result is not NotImplemented:
#     216         return result
#
# File pandas/_libs/ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
# --> 113 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\arraylike.py:202, in OpsMixin.__rsub__(self, other)
#     200 @unpack_zerodim_and_defer("__rsub__")
#     201 def __rsub__(self, other):
# --> 202     return self._arith_method(other, roperator.rsub)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\arrays\string_.py:1218, in StringArray._cmp_method(self, other, op)
#    1216 result = np.empty_like(self._ndarray, dtype="object")
#    1217 result[mask] = self.dtype.na_value
# -> 1218 result[valid] = op(self._ndarray[valid], other)
#    1219 if isinstance(other, Path):
#    1220     # GH#61940
#    1221     return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\roperator.py:16, in rsub(left, right)
#      15 def rsub(left, right):
# ---> 16     return right - left
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
df["initial_price"] = pd.to_numeric(df["initial_price"], errors="coerce")
df["final_price"] = pd.to_numeric(df["final_price"], errors="coerce")

df["price_difference"] = df["initial_price"] - df["final_price"]

df.to_csv("cleaned_dataset.csv", index=False)

print("Done")
# Out:
# Done

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0          NaN      INR
# 1     4.5             67           2899      35.0          NaN      INR
# 2     4.4            226           2999      65.0          NaN      INR
# 3     4.4           1052           1675      52.0          NaN      INR
# 4     4.7             12           2899      17.0          NaN      INR
#
#                                               images  ... what_customers_said  \
# 0  http://assets.myntassets.com/assets/images/837...  ...                 NaN
# 1  http://assets.myntassets.com/assets/images/913...  ...                 NaN
# 2  http://assets.myntassets.com/assets/images/176...  ...                 NaN
# 3  http://assets.myntassets.com/assets/images/137...  ...                 NaN
# 4  http://assets.myntassets.com/assets/images/pro...  ...                 NaN
#
#   seller_name                                              sizes  \
# 0         NaN                               [{"size":"Onesize"}]
# 1         NaN                               [{"size":"Onesize"}]
# 2         NaN                                     [{"size":"S"}]
# 3         NaN                               [{"size":"Onesize"}]
# 4         NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                NaN
# 1                              ["rw-9136281_cae700"]                NaN
# 2  ["https://videos.myntassets.com/assets/videos/...                NaN
# 3  ["https://videos.myntassets.com/assets/videos/...                NaN
# 4                                                NaN                NaN
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                          NaN         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category  \
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
#
#   price_difference
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 25 columns]

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# D:\Document\archive
# ['.ipynb_checkpoints', 'backpacks.csv', 'Basic_Data_Cleaning.ipynb', 'bath-robe.csv', 'bath-towels.csv', 'bathroom-accessories.csv', 'bedsheets.csv', 'belts.csv', 'bodysuit.csv', 'boots.csv', 'boxers.csv', 'bra.csv', 'bracelet.csv', 'briefs.csv', 'camisoles.csv', 'candle-holders.csv', 'caps.csv', 'casual-shoes.csv', 'chair-cover.csv', 'cleaned_dataset.csv', 'clothing-set.csv', 'clutches.csv', 'co-ords.csv', 'Combined_dataset.csv', 'curtains-and-sheers.csv', 'cutlery.csv', 'dinnerware.csv', 'dresses.csv', 'duffel-bag.csv', 'dungarees.csv', 'dupatta.csv', 'earrings.csv', 'ethnic-dresses.csv', 'face-moisturisers.csv', 'face-wash-and-cleanser.csv', 'flats.csv', 'flip-flops.csv', 'floor-mats--dhurries.csv', 'formal-shoes.csv', 'foundation.csv', 'gloves.csv', 'hair-accessory.csv', 'hair-brush-and-comb.csv', 'hair-cream-and-mask.csv', 'hair-masks.csv', 'handbags.csv', 'headphones.csv', 'heels.csv', 'home-fragrance-set.csv', 'innerwear-vests.csv', 'jackets.csv', 'jeans.csv', 'jumpsuit.csv', 'kurta-sets.csv', 'kurtas.csv', 'kurtis.csv', 'lipstick.csv', 'lounge-pants.csv', 'lounge-shorts.csv', 'lounge-tshirts.csv', 'mangalsutra.csv', 'mobile-accessories.csv', 'night-suits.csv', 'nightdress.csv', 'outdoor-masks.csv', 'palazzos.csv', 'perfume-and-body-mist.csv', 'pillow-covers.csv', 'README.md', 'README.md.txt', 'ring.csv', 'runners.csv', 'sandals.csv', 'saree-blouse.csv', 'sarees.csv', 'scarves.csv', 'shampoo-and-conditioner.csv', 'shaving-essentials.csv', 'sherwani.csv', 'shirts.csv', 'shorts.csv', 'showpieces.csv', 'skirts.csv', 'sports-shoes.csv', 'sunglasses.csv', 'sweaters.csv', 'sweatshirts.csv', 'swim-tops.csv', 'table-covers.csv', 'thermal-bottoms.csv', 'tights.csv', 'tops.csv', 'towel-set.csv', 'track-pants.csv', 'trolley-bag.csv', 'trousers.csv', 'trunk.csv', 'tshirts.csv', 'tunics.csv', 'Untitled.ipynb', 'wall-art.csv', 'wallets.csv', 'watches.csv', 'yoga-mats.csv']
